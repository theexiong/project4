# %%
# Import the required libraries and dependencies
import pandas as pd
import hvplot.pandas
import os
import tensorflow as tf

import findspark
findspark.init()

from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="daf465d2-0f51-41e5-8164-22d1af1144f1" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"96792e5e-8581-44ad-9e37-5127d74af7af":{"version":"3.4.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"c62442f1cdff4d179fd2d35522e9f697","client_comm_id":"d2b253a86f584dd59dc92fcd5ac59960"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"96792e5e-8581-44ad-9e37-5127d74af7af","roots":{"p1002":"daf465d2-0f51-41e5-8164-22d1af1144f1"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
# Import packages
from pyspark.sql import SparkSession
import time

# Create a SparkSession
spark = SparkSession.builder\
    .appName("SparkSQL")\
    .config("spark.sql.debug.maxToStringFields", 2000)\
    .config("spark.driver.memory", "2g")\
    .getOrCreate()

# Set the partitions to 4 or 8. 
spark.conf.set("spark.sql.shuffle.partitions", 8)

# %%
#  Import and read the Ghibli_characters.csv
df = pd.read_csv("Resources/Ghibli_characters.csv")
df.head()
# Out:
#       character name     age  height (cm)           special powers  \
# 0             Totoro  1302.0        215.0    Flight, teleportation
# 1            Chihiro    10.0        120.0                      NaN
# 2               Haku    12.0        180.0    Flight, shapeshifting
# 3  Princess Mononoke    15.0        150.0                      NaN
# 4           Ashitaka    17.0        170.0  Super strength, agility
#
#   country / place of residence  gender          Species               movie  \
# 0                        Japan    Male           Spirit  My Neighbor Totoro
# 1                        Japan  Female            Human       Spirited Away
# 2                        Japan    Male  Spirit (dragon)       Spirited Away
# 3                        Japan  Female            Human   Princess Mononoke
# 4                        Japan    Male            Human   Princess Mononoke
#
#    release date
# 0          1988
# 1          2001
# 2          2001
# 3          1997
# 4          1997

# %%
# Read in data from csv file
from pyspark import SparkFiles
file = "Resources/Ghibli_characters.csv"
spark.sparkContext.addFile(file)

# %%
# Assign csv file as a variable 
SG_characters = spark.read.csv(SparkFiles.get("Ghibli_characters.csv"), sep=",", header=True)

# Create a temp view from csv file
SG_characters.createOrReplaceTempView('SG_characters')

# %%
# Display SG_characters temp view
SG_characters.show()
# Out:
# +--------------------+----+-----------+--------------------+----------------------------+------+--------------------+--------------------+------------+
# |      character name| age|height (cm)|      special powers|country / place of residence|gender|             Species|               movie|release date|
# +--------------------+----+-----------+--------------------+----------------------------+------+--------------------+--------------------+------------+
# |              Totoro|1302|        215|Flight, teleporta...|                       Japan|  Male|              Spirit|  My Neighbor Totoro|        1988|
# |             Chihiro|  10|        120|                 N/A|                       Japan|Female|               Human|       Spirited Away|        2001|
# |                Haku|  12|        180|Flight, shapeshif...|                       Japan|  Male|     Spirit (dragon)|       Spirited Away|        2001|
# |   Princess Mononoke|  15|        150|                 N/A|                       Japan|Female|               Human|   Princess Mononoke|        1997|
# |            Ashitaka|  17|        170|Super strength, a...|                       Japan|  Male|               Human|   Princess Mononoke|        1997|
# |             Satsuki|   4|        110|                 N/A|                       Japan|Female|               Human|  My Neighbor Totoro|        1988|
# |                 Mei|   2|        100|                 N/A|                       Japan|Female|               Human|  My Neighbor Totoro|        1988|
# |                Jiji|  13|         20|       Shapeshifting|                       Japan|  Male|                 Cat|Kiki's Delivery S...|        1989|
# |                Kiki|  13|        130|Flight, broomstic...|                       Japan|Female|               Witch|Kiki's Delivery S...|        1989|
# |                Howl|  27|        180|Shapeshifting, fl...|                       Wales|  Male|              Wizard|Howl's Moving Castle|        2004|
# |              Sophie|  18|        150|                 N/A|                      Europe|Female|               Human|Howl's Moving Castle|        2004|
# |            Calcifer| N/A|         30|   Fire manipulation|                       Wales|  Male|          Fire demon|Howl's Moving Castle|        2004|
# |            Nausicaä|  16|        150|Telepathy, commun...|                       Japan|Female|               Human|Nausicaä of the V...|        1984|
# |              Ningyo| N/A|        120|                 N/A|                       Japan|  Male|Mermaid-like crea...|When Marnie Was T...|        2014|
# |                 San|  15|        150|Super strength, a...|                       Japan|Female|        Wolf goddess|   Princess Mononoke|        1997|
# |                Pazu|  10|        120|                 N/A|                      Europe|  Male|               Human|   Castle in the Sky|        1986|
# |              Sheeta|  10|        120|Telekinesis, cont...|                      Europe|Female|               Human|   Castle in the Sky|        1986|
# |             Shizuku|  12|        120|                 N/A|                       Japan|Female|               Human|Whisper of the Heart|        1995|
# |               Seiji|  12|        120|                 N/A|                       Japan|  Male|               Human|Whisper of the Heart|        1995|
# |Baron Humbert von...|  23|        180|Shapeshifting int...|                      Europe|  Male|           Human cat|     The Cat Returns|        2002|
# +--------------------+----+-----------+--------------------+----------------------------+------+--------------------+--------------------+------------+
# only showing top 20 rows

# %%
# query distinct species
start_time = time.time()

species_df = spark.sql("""
select distinct Species, count(Species)
from SG_characters
group by Species
""")

species_df.show()

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# +--------------------+--------------+
# |             Species|count(Species)|
# +--------------------+--------------+
# |        Wolf goddess|             1|
# |           Human cat|             1|
# |            Boar god|             1|
# |              Spirit|             2|
# |               Witch|             1|
# |                Fish|             1|
# |     Spirit (dragon)|             1|
# |                 Cat|             2|
# |              Wizard|             1|
# |Mermaid-like crea...|             1|
# |           Scarecrow|             1|
# |       Moon princess|             1|
# |       Forest spirit|             1|
# |               Human|            40|
# |          Fire demon|             1|
# +--------------------+--------------+
#
# --- 0.7102868556976318 seconds ---

# %%
# Display how many movies Studio Ghibli has made
spark.sql("""
select distinct movie
from SG_characters
""").show()
# Out:
# +--------------------+
# |               movie|
# +--------------------+
# |Nausicaä of the V...|
# |               Ponyo|
# |       Spirited Away|
# |Whisper of the Heart|
# |Grave of the Fire...|
# |   Princess Mononoke|
# |  My Neighbor Totoro|
# |When Marnie Was T...|
# |The Tale of the P...|
# |Kiki's Delivery S...|
# |   Castle in the Sky|
# |Howl's Moving Castle|
# |     The Cat Returns|
# |         Porco Rosso|
# +--------------------+

# %%
# clean dataframe and drop non-beneficial 
cleanedCharacters = df.drop(columns = ['character name','movie', 'release date'], axis=1)
cleanedCharacters.head()
# Out:
#       age  height (cm)           special powers country / place of residence  \
# 0  1302.0        215.0    Flight, teleportation                        Japan
# 1    10.0        120.0                      NaN                        Japan
# 2    12.0        180.0    Flight, shapeshifting                        Japan
# 3    15.0        150.0                      NaN                        Japan
# 4    17.0        170.0  Super strength, agility                        Japan
#
#    gender          Species
# 0    Male           Spirit
# 1  Female            Human
# 2    Male  Spirit (dragon)
# 3  Female            Human
# 4    Male            Human

# %%
# Scale price data, return, and variance values
data_scaled = StandardScaler().fit_transform(
    cleanedCharacters[["age", "height (cm)"]]
)

# %%
# Create a DataFrame with the scaled data
df_data_scaled = pd.DataFrame(
    data_scaled,
    columns=["age", "height (cm)"]
)

# Display sample data
df_data_scaled.head()
# Out:
#         age  height (cm)
# 0  5.884276     2.080366
# 1 -0.269684    -0.396138
# 2 -0.260157     1.167969
# 3 -0.245868     0.385915
# 4 -0.236342     0.907285

# %%
# get_dummies to convert categorical values to numerical values
ghibli_dummies = pd.get_dummies(cleanedCharacters["special powers"])
ghibli_dummies.head()
# Out:
#    Fire manipulation  Flight, broomstick flying  Flight, shapeshifting  \
# 0              False                      False                  False
# 1              False                      False                  False
# 2              False                      False                   True
# 3              False                      False                  False
# 4              False                      False                  False
#
#    Flight, teleportation  Shape-shifting, size manipulation  Shapeshifting  \
# 0                   True                              False          False
# 1                  False                              False          False
# 2                  False                              False          False
# 3                  False                              False          False
# 4                  False                              False          False
#
#    Shapeshifting into a cat  Shapeshifting into a fish  \
# 0                     False                      False
# 1                     False                      False
# 2                     False                      False
# 3                     False                      False
# 4                     False                      False
#
#    Shapeshifting, flight, magic  Super strength, agility  \
# 0                         False                    False
# 1                         False                    False
# 2                         False                    False
# 3                         False                    False
# 4                         False                     True
#
#    Super strength, agility, communication with wolves  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Super strength, agility, shapeshifting into a boar  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Super strength, agility, telekinesis  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#    Telekinesis, control over levitation crystals  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    Telepathy, communication with insects
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False

# %%
print(ghibli_dummies)
# Out:
#     Fire manipulation  Flight, broomstick flying  Flight, shapeshifting  \
# 0               False                      False                  False
# 1               False                      False                  False
# 2               False                      False                   True
# 3               False                      False                  False
# 4               False                      False                  False
# 5               False                      False                  False
# 6               False                      False                  False
# 7               False                      False                  False
# 8               False                       True                  False
# 9               False                      False                  False
# 10              False                      False                  False
# 11               True                      False                  False
# 12              False                      False                  False
# 13              False                      False                  False
# 14              False                      False                  False
# 15              False                      False                  False
# 16              False                      False                  False
# 17              False                      False                  False
# 18              False                      False                  False
# 19              False                      False                  False
# 20              False                      False                  False
# 21              False                      False                  False
# 22              False                      False                  False
# 23              False                      False                  False
# 24              False                      False                  False
# 25              False                      False                  False
# 26              False                      False                  False
# 27              False                      False                  False
# 28              False                      False                  False
# 29              False                      False                  False
# 30              False                      False                  False
# 31              False                      False                  False
# 32              False                      False                  False
# 33              False                      False                  False
# 34              False                      False                  False
# 35              False                      False                  False
# 36              False                      False                  False
# 37              False                      False                  False
# 38              False                      False                  False
# 39              False                      False                  False
# 40              False                      False                  False
# 41              False                      False                  False
# 42              False                      False                  False
# 43              False                      False                  False
# 44              False                      False                  False
# 45              False                      False                  False
# 46              False                      False                  False
# 47              False                      False                  False
# 48              False                      False                  False
# 49              False                      False                  False
# 50              False                      False                  False
# 51              False                      False                  False
# 52              False                      False                  False
# 53              False                      False                  False
# 54              False                      False                  False
# 55              False                      False                  False
#
#     Flight, teleportation  Shape-shifting, size manipulation  Shapeshifting  \
# 0                    True                              False          False
# 1                   False                              False          False
# 2                   False                              False          False
# 3                   False                              False          False
# 4                   False                              False          False
# 5                   False                              False          False
# 6                   False                              False          False
# 7                   False                              False           True
# 8                   False                              False          False
# 9                   False                              False          False
# 10                  False                              False          False
# 11                  False                              False          False
# 12                  False                              False          False
# 13                  False                              False          False
# 14                  False                              False          False
# 15                  False                              False          False
# 16                  False                              False          False
# 17                  False                              False          False
# 18                  False                              False          False
# 19                  False                              False          False
# 20                  False                              False          False
# 21                  False                              False          False
# 22                  False                              False          False
# 23                  False                              False          False
# 24                  False                               True          False
# 25                  False                              False          False
# 26                  False                              False          False
# 27                  False                              False          False
# 28                  False                              False          False
# 29                  False                              False          False
# 30                  False                              False          False
# 31                  False                              False          False
# 32                  False                              False          False
# 33                  False                               True          False
# 34                  False                               True          False
# 35                  False                               True          False
# 36                  False                               True          False
# 37                  False                               True          False
# 38                  False                              False          False
# 39                  False                               True          False
# 40                  False                               True          False
# 41                  False                               True          False
# 42                  False                               True          False
# 43                  False                               True          False
# 44                  False                               True          False
# 45                  False                               True          False
# 46                  False                               True          False
# 47                  False                               True          False
# 48                  False                               True          False
# 49                  False                               True          False
# 50                  False                              False          False
# 51                  False                              False          False
# 52                  False                              False          False
# 53                  False                              False          False
# 54                  False                              False          False
# 55                  False                              False          False
#
#     Shapeshifting into a cat  Shapeshifting into a fish  \
# 0                      False                      False
# 1                      False                      False
# 2                      False                      False
# 3                      False                      False
# 4                      False                      False
# 5                      False                      False
# 6                      False                      False
# 7                      False                      False
# 8                      False                      False
# 9                      False                      False
# 10                     False                      False
# 11                     False                      False
# 12                     False                      False
# 13                     False                      False
# 14                     False                      False
# 15                     False                      False
# 16                     False                      False
# 17                     False                      False
# 18                     False                      False
# 19                      True                      False
# 20                      True                      False
# 21                      True                      False
# 22                     False                       True
# 23                     False                      False
# 24                     False                      False
# 25                     False                      False
# 26                     False                      False
# 27                     False                      False
# 28                     False                      False
# 29                     False                      False
# 30                     False                      False
# 31                     False                      False
# 32                     False                      False
# 33                     False                      False
# 34                     False                      False
# 35                     False                      False
# 36                     False                      False
# 37                     False                      False
# 38                     False                      False
# 39                     False                      False
# 40                     False                      False
# 41                     False                      False
# 42                     False                      False
# 43                     False                      False
# 44                     False                      False
# 45                     False                      False
# 46                     False                      False
# 47                     False                      False
# 48                     False                      False
# 49                     False                      False
# 50                     False                      False
# 51                     False                      False
# 52                     False                      False
# 53                     False                      False
# 54                     False                      False
# 55                     False                      False
#
#     Shapeshifting, flight, magic  Super strength, agility  \
# 0                          False                    False
# 1                          False                    False
# 2                          False                    False
# 3                          False                    False
# 4                          False                     True
# 5                          False                    False
# 6                          False                    False
# 7                          False                    False
# 8                          False                    False
# 9                           True                    False
# 10                         False                    False
# 11                         False                    False
# 12                         False                    False
# 13                         False                    False
# 14                         False                    False
# 15                         False                    False
# 16                         False                    False
# 17                         False                    False
# 18                         False                    False
# 19                         False                    False
# 20                         False                    False
# 21                         False                    False
# 22                         False                    False
# 23                         False                    False
# 24                         False                    False
# 25                         False                    False
# 26                         False                    False
# 27                         False                    False
# 28                         False                    False
# 29                         False                    False
# 30                         False                    False
# 31                         False                    False
# 32                         False                    False
# 33                         False                    False
# 34                         False                    False
# 35                         False                    False
# 36                         False                    False
# 37                         False                    False
# 38                         False                    False
# 39                         False                    False
# 40                         False                    False
# 41                         False                    False
# 42                         False                    False
# 43                         False                    False
# 44                         False                    False
# 45                         False                    False
# 46                         False                    False
# 47                         False                    False
# 48                         False                    False
# 49                         False                    False
# 50                         False                    False
# 51                         False                    False
# 52                         False                    False
# 53                         False                    False
# 54                         False                    False
# 55                         False                    False
#
#     Super strength, agility, communication with wolves  \
# 0                                               False
# 1                                               False
# 2                                               False
# 3                                               False
# 4                                               False
# 5                                               False
# 6                                               False
# 7                                               False
# 8                                               False
# 9                                               False
# 10                                              False
# 11                                              False
# 12                                              False
# 13                                              False
# 14                                               True
# 15                                              False
# 16                                              False
# 17                                              False
# 18                                              False
# 19                                              False
# 20                                              False
# 21                                              False
# 22                                              False
# 23                                              False
# 24                                              False
# 25                                              False
# 26                                              False
# 27                                              False
# 28                                              False
# 29                                              False
# 30                                              False
# 31                                              False
# 32                                              False
# 33                                              False
# 34                                              False
# 35                                              False
# 36                                              False
# 37                                              False
# 38                                              False
# 39                                              False
# 40                                              False
# 41                                              False
# 42                                              False
# 43                                              False
# 44                                              False
# 45                                              False
# 46                                              False
# 47                                              False
# 48                                              False
# 49                                              False
# 50                                              False
# 51                                              False
# 52                                              False
# 53                                              False
# 54                                              False
# 55                                              False
#
#     Super strength, agility, shapeshifting into a boar  \
# 0                                               False
# 1                                               False
# 2                                               False
# 3                                               False
# 4                                               False
# 5                                               False
# 6                                               False
# 7                                               False
# 8                                               False
# 9                                               False
# 10                                              False
# 11                                              False
# 12                                              False
# 13                                              False
# 14                                              False
# 15                                              False
# 16                                              False
# 17                                              False
# 18                                              False
# 19                                              False
# 20                                              False
# 21                                              False
# 22                                              False
# 23                                              False
# 24                                              False
# 25                                              False
# 26                                              False
# 27                                               True
# 28                                              False
# 29                                              False
# 30                                              False
# 31                                              False
# 32                                              False
# 33                                              False
# 34                                              False
# 35                                              False
# 36                                              False
# 37                                              False
# 38                                              False
# 39                                              False
# 40                                              False
# 41                                              False
# 42                                              False
# 43                                              False
# 44                                              False
# 45                                              False
# 46                                              False
# 47                                              False
# 48                                              False
# 49                                              False
# 50                                              False
# 51                                              False
# 52                                              False
# 53                                              False
# 54                                              False
# 55                                              False
#
#     Super strength, agility, telekinesis  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# 5                                  False
# 6                                  False
# 7                                  False
# 8                                  False
# 9                                  False
# 10                                 False
# 11                                 False
# 12                                 False
# 13                                 False
# 14                                 False
# 15                                 False
# 16                                 False
# 17                                 False
# 18                                 False
# 19                                 False
# 20                                 False
# 21                                 False
# 22                                 False
# 23                                 False
# 24                                 False
# 25                                  True
# 26                                  True
# 27                                 False
# 28                                 False
# 29                                 False
# 30                                 False
# 31                                 False
# 32                                 False
# 33                                 False
# 34                                 False
# 35                                 False
# 36                                 False
# 37                                 False
# 38                                 False
# 39                                 False
# 40                                 False
# 41                                 False
# 42                                 False
# 43                                 False
# 44                                 False
# 45                                 False
# 46                                 False
# 47                                 False
# 48                                 False
# 49                                 False
# 50                                 False
# 51                                 False
# 52                                 False
# 53                                 False
# 54                                 False
# 55                                 False
#
#     Telekinesis, control over levitation crystals  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
# 5                                           False
# 6                                           False
# 7                                           False
# 8                                           False
# 9                                           False
# 10                                          False
# 11                                          False
# 12                                          False
# 13                                          False
# 14                                          False
# 15                                          False
# 16                                           True
# 17                                          False
# 18                                          False
# 19                                          False
# 20                                          False
# 21                                          False
# 22                                          False
# 23                                          False
# 24                                          False
# 25                                          False
# 26                                          False
# 27                                          False
# 28                                          False
# 29                                          False
# 30                                          False
# 31                                          False
# 32                                          False
# 33                                          False
# 34                                          False
# 35                                          False
# 36                                          False
# 37                                          False
# 38                                          False
# 39                                          False
# 40                                          False
# 41                                          False
# 42                                          False
# 43                                          False
# 44                                          False
# 45                                          False
# 46                                          False
# 47                                          False
# 48                                          False
# 49                                          False
# 50                                          False
# 51                                          False
# 52                                          False
# 53                                          False
# 54                                          False
# 55                                          False
#
#     Telepathy, communication with insects
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# 5                                   False
# 6                                   False
# 7                                   False
# 8                                   False
# 9                                   False
# 10                                  False
# 11                                  False
# 12                                   True
# 13                                  False
# 14                                  False
# 15                                  False
# 16                                  False
# 17                                  False
# 18                                  False
# 19                                  False
# 20                                  False
# 21                                  False
# 22                                  False
# 23                                  False
# 24                                  False
# 25                                  False
# 26                                  False
# 27                                  False
# 28                                  False
# 29                                  False
# 30                                  False
# 31                                  False
# 32                                  False
# 33                                  False
# 34                                  False
# 35                                  False
# 36                                  False
# 37                                  False
# 38                                  False
# 39                                  False
# 40                                  False
# 41                                  False
# 42                                  False
# 43                                  False
# 44                                  False
# 45                                  False
# 46                                  False
# 47                                  False
# 48                                  False
# 49                                  False
# 50                                  False
# 51                                  False
# 52                                  False
# 53                                  False
# 54                                  False
# 55                                  False

# %%
# Look at Species value counts for binning
species_class = df['Species']
species_class.head()
# Out:
# 0             Spirit
# 1              Human
# 2    Spirit (dragon)
# 3              Human
# 4              Human
# Name: Species, dtype: object

# %%
# Create All Human species classifications to be replaced with 1
Humans = species_class[species_class == "Human"]

# Replace in dataframe
for species in Humans:
    df['Species'] = df['Species'].replace(species,"1")

# Check to make sure binning was successful
df['Species']
# Out:
# 0                    Spirit
# 1                         1
# 2           Spirit (dragon)
# 3                         1
# 4                         1
# 5                         1
# 6                         1
# 7                       Cat
# 8                     Witch
# 9                    Wizard
# 10                        1
# 11               Fire demon
# 12                        1
# 13    Mermaid-like creature
# 14             Wolf goddess
# 15                        1
# 16                        1
# 17                        1
# 18                        1
# 19                Human cat
# 20                        1
# 21                      Cat
# 22                     Fish
# 23                        1
# 24                        1
# 25                        1
# 26            Moon princess
# 27                 Boar god
# 28                        1
# 29                        1
# 30                        1
# 31                        1
# 32                        1
# 33                   Spirit
# 34                        1
# 35                        1
# 36                        1
# 37                        1
# 38                        1
# 39            Forest spirit
# 40                        1
# 41                Scarecrow
# 42                        1
# 43                        1
# 44                        1
# 45                        1
# 46                        1
# 47                        1
# 48                        1
# 49                        1
# 50                        1
# 51                        1
# 52                        1
# 53                        1
# 54                        1
# 55                        1
# Name: Species, dtype: object

# %%
# Create All Human species classifications to be replaced with 1
OtherSpecies = species_class[species_class != "Human"]

# Replace in dataframe
for species in OtherSpecies:
    df['Species'] = df['Species'].replace(species,"0")

# Check to make sure binning was successful
df['Species']
# Out:
# 0     0
# 1     1
# 2     0
# 3     1
# 4     1
# 5     1
# 6     1
# 7     0
# 8     0
# 9     0
# 10    1
# 11    0
# 12    1
# 13    0
# 14    0
# 15    1
# 16    1
# 17    1
# 18    1
# 19    0
# 20    1
# 21    0
# 22    0
# 23    1
# 24    1
# 25    1
# 26    0
# 27    0
# 28    1
# 29    1
# 30    1
# 31    1
# 32    1
# 33    0
# 34    1
# 35    1
# 36    1
# 37    1
# 38    1
# 39    0
# 40    1
# 41    0
# 42    1
# 43    1
# 44    1
# 45    1
# 46    1
# 47    1
# 48    1
# 49    1
# 50    1
# 51    1
# 52    1
# 53    1
# 54    1
# 55    1
# Name: Species, dtype: object

# %%
# split data into features and target arrays
y = df['Species'].astype('float64')
X = ghibli_dummies.values

# %%
# show all X values
X[:5]
# Out:
# array([[False, False, False,  True, False, False, False, False, False,
#         False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False],
#        [False, False,  True, False, False, False, False, False, False,
#         False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#          True, False, False, False, False, False]])

# %%
# show all y values
y[:10]
# Out:
# 0    0.0
# 1    1.0
# 2    0.0
# 3    1.0
# 4    1.0
# 5    1.0
# 6    1.0
# 7    0.0
# 8    0.0
# 9    0.0
# Name: Species, dtype: float64

# %%
# split data into training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=17)
print("Training Data Info")
print("Training Data Shape:", X_train.shape)
print("Training Data Labels Shape:", y_train.shape)
# Out:
# Training Data Info
# Training Data Shape: (42, 15)
# Training Data Labels Shape: (42,)

# %%
# Create Standard Scaler
scaler = StandardScaler()

# Fit scaler to training data
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=10, activation='relu', input_dim=15))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=7, activation='relu'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=13, activation='tanh'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 10)                160
#
#  dense_5 (Dense)             (None, 7)                 77
#
#  dense_6 (Dense)             (None, 13)                104
#
#  dense_7 (Dense)             (None, 1)                 14
#
# =================================================================
# Total params: 355 (1.39 KB)
# Trainable params: 355 (1.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 1s 3ms/step - loss: 0.6914 - accuracy: 0.5714
# Epoch 2/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6844 - accuracy: 0.5714
# Epoch 3/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6782 - accuracy: 0.7143
# Epoch 4/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6722 - accuracy: 0.7143
# Epoch 5/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.6658 - accuracy: 0.7143
# Epoch 6/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6603 - accuracy: 0.7143
# Epoch 7/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6545 - accuracy: 0.7143
# Epoch 8/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6491 - accuracy: 0.7381
# Epoch 9/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6434 - accuracy: 0.7381
# Epoch 10/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.6383 - accuracy: 0.7381
# Epoch 11/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.6336 - accuracy: 0.7381
# Epoch 12/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.6287 - accuracy: 0.7381
# Epoch 13/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6243 - accuracy: 0.7381
# Epoch 14/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6199 - accuracy: 0.7381
# Epoch 15/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6151 - accuracy: 0.7381
# Epoch 16/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6113 - accuracy: 0.7381
# Epoch 17/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.6070 - accuracy: 0.7381
# Epoch 18/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6027 - accuracy: 0.7381
# Epoch 19/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5986 - accuracy: 0.7619
# Epoch 20/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5948 - accuracy: 0.7619
# Epoch 21/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5909 - accuracy: 0.7619
# Epoch 22/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5867 - accuracy: 0.7619
# Epoch 23/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5829 - accuracy: 0.7857
# Epoch 24/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5792 - accuracy: 0.7857
# Epoch 25/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5754 - accuracy: 0.7857
# Epoch 26/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5715 - accuracy: 0.7857
# Epoch 27/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5681 - accuracy: 0.7857
# Epoch 28/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5643 - accuracy: 0.7857
# Epoch 29/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5606 - accuracy: 0.7857
# Epoch 30/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5571 - accuracy: 0.7857
# Epoch 31/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5534 - accuracy: 0.7857
# Epoch 32/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5504 - accuracy: 0.7857
# Epoch 33/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5464 - accuracy: 0.7857
# Epoch 34/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5429 - accuracy: 0.7857
# Epoch 35/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5394 - accuracy: 0.7857
# Epoch 36/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5357 - accuracy: 0.7857
# Epoch 37/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5318 - accuracy: 0.7857
# Epoch 38/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5272 - accuracy: 0.7857
# Epoch 39/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5232 - accuracy: 0.7857
# Epoch 40/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5190 - accuracy: 0.7857
# Epoch 41/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5149 - accuracy: 0.7857
# Epoch 42/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5107 - accuracy: 0.7857
# Epoch 43/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5064 - accuracy: 0.7857
# Epoch 44/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5023 - accuracy: 0.7857
# Epoch 45/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.4981 - accuracy: 0.7857
# Epoch 46/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4942 - accuracy: 0.7857
# Epoch 47/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4906 - accuracy: 0.7857
# Epoch 48/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4866 - accuracy: 0.7857
# Epoch 49/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4829 - accuracy: 0.7857
# Epoch 50/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.4792 - accuracy: 0.7857
# Epoch 51/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4753 - accuracy: 0.7857
# Epoch 52/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.4722 - accuracy: 0.7857
# Epoch 53/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4681 - accuracy: 0.7857
# Epoch 54/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4644 - accuracy: 0.8095
# Epoch 55/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4610 - accuracy: 0.8095
# Epoch 56/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4575 - accuracy: 0.8095
# Epoch 57/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4538 - accuracy: 0.8095
# Epoch 58/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4505 - accuracy: 0.8095
# Epoch 59/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4471 - accuracy: 0.8095
# Epoch 60/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4439 - accuracy: 0.8095
# Epoch 61/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4407 - accuracy: 0.8095
# Epoch 62/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4377 - accuracy: 0.8095
# Epoch 63/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.4342 - accuracy: 0.8095
# Epoch 64/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.4315 - accuracy: 0.8095
# Epoch 65/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.4284 - accuracy: 0.8095
# Epoch 66/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.4254 - accuracy: 0.8095
# Epoch 67/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.4225 - accuracy: 0.8095
# Epoch 68/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4196 - accuracy: 0.8095
# Epoch 69/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.4177 - accuracy: 0.8095
# Epoch 70/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4144 - accuracy: 0.8095
# Epoch 71/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.4122 - accuracy: 0.8095
# Epoch 72/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4097 - accuracy: 0.8333
# Epoch 73/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.4074 - accuracy: 0.8333
# Epoch 74/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4053 - accuracy: 0.8333
# Epoch 75/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4033 - accuracy: 0.8571
# Epoch 76/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4007 - accuracy: 0.8571
# Epoch 77/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3988 - accuracy: 0.8571
# Epoch 78/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3972 - accuracy: 0.8571
# Epoch 79/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3950 - accuracy: 0.8571
# Epoch 80/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3931 - accuracy: 0.8571
# Epoch 81/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3913 - accuracy: 0.8571
# Epoch 82/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3896 - accuracy: 0.8571
# Epoch 83/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3878 - accuracy: 0.8571
# Epoch 84/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3866 - accuracy: 0.8571
# Epoch 85/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3847 - accuracy: 0.8571
# Epoch 86/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3831 - accuracy: 0.8571
# Epoch 87/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3817 - accuracy: 0.8571
# Epoch 88/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3800 - accuracy: 0.8571
# Epoch 89/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3788 - accuracy: 0.8571
# Epoch 90/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3774 - accuracy: 0.8571
# Epoch 91/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3764 - accuracy: 0.8571
# Epoch 92/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3749 - accuracy: 0.8571
# Epoch 93/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3736 - accuracy: 0.8571
# Epoch 94/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3723 - accuracy: 0.8571
# Epoch 95/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3710 - accuracy: 0.8571
# Epoch 96/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3698 - accuracy: 0.8571
# Epoch 97/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3690 - accuracy: 0.8571
# Epoch 98/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3675 - accuracy: 0.8571
# Epoch 99/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3667 - accuracy: 0.8571
# Epoch 100/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3652 - accuracy: 0.8571

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 1/1 - 0s - loss: 0.5357 - accuracy: 0.7857 - 115ms/epoch - 115ms/step
# Loss: 0.5357179641723633, Accuracy: 0.7857142686843872
